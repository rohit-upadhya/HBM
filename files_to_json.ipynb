# %%
import json
import glob

# %%
# data = [json.loads(line) for line in open('/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/ECHR_Dataset/EN_train/001-4500.json',"r")]
# # data = [json.loads(line) for line in open('dev.json',"r")]
# g = open("test.txt", "w+")
# i = 0
# for j in data:
#     print(j)
# #     if(len(j['violated_articles']) != 0):
# #         print(j['violated_articles'])
# #         i = i + 1
# # print('out now',i)
# g.close()

# # 001-4500

# %%
files = glob.glob("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/ECHR_Dataset/EN_train/*.json")

# %%
k = 0
l = 0
g = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train_pos.json", "w+")
g.write("")
g.close()
listing = []
for i in files:
    data = [json.loads(line) for line in open(i,"r")]
#     string__ = ','.join(str("\""+item+"\"") for item in data[0]['TEXT'])
    if(len(data[0]['VIOLATED_ARTICLES']) == 0):
#         dictionary = {
# #             "label": "0",
#             "text": ' '.join(data[0]['TEXT'])
#         }
    #   print(j['CONCLUSION'])
        k = k + 1
#         listing.append(dictionary)
    else:
        print(data[0]['VIOLATED_ARTICLES'])
        dictionary = {
#             "label": "1",
            "text": ' '.join(data[0]['TEXT'])
        }
        l = l + 1
        listing.append(dictionary)
    
# dictionary2 = {"data": listing}
# json_object = json.dumps(dictionary2, indent=2)
#     print(json_object)
# g = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train.json", "a+")
# g.write(json_object)
# g.write("\n")
    
# print('out now',k)
# g.close()
# Out:
# ['2', '6']
# ['13', '6']
# ['5']
# ['13', '6']
# ['6']
# ['5', '6']
# ['6']
# ['6']
# ['14', '8']
# ['3', '6']
# ['6']
# ['13', '6']
# ['6']
# ['5']
# ['6']
# ['8']
# ['8']
# ['6']
# ['6']
# ['5']
# ['6']
# ['5']
# ['3', '5']
# ['13', '6']
# ['13', '6']
# ['6']
# ['6']
# ['7']
# ['13', '3']
# ['13', '2']
# ['6']
# ['5']
# ['5', '8']
# ['13', '3', '5']
# ['6']
# ['3', '34', '5']
# ['6']
# ['14', '8']
# ['6']
# ['13', '2', '34', '5']
# ['13', '6']
# ['6', 'P1']
# ['6']
# ['6']
# ['13']
# ['2']
# ['6']
# ['5']
# ['6']
# ['11']
# ['6', 'P1']
# ['8']
# ['11', '6', '7']
# ['6']
# ['8']
# ['13', '8']
# ['5']
# ['34', '5', '8']
# ['5', '6']
# ['3', '8']
# ['6', 'P1']
# ['6']
# ['13', '3']
# ['5']
# ['5', '6']
# ['13', '6']
# ['6']
# ['3']
# ['6']
# ['2', '3', '38']
# ['5']
# ['6']
# ['6']
# ['6']
# ['3']
# ['13', '9', 'P1']
# ['6']
# ['8']
# ['6']
# ['6']
# ['8']
# ['10', '6']
# ['5']
# ['13', '3', '5', '6']
# ['6']
# ['5', '6', 'P1']
# ['3', '5']
# ['10']
# ['3', '5', '6']
# ['6']
# ...

# %%
files = glob.glob("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/ECHR_Dataset/EN_test/*.json")

# %%
# k = 0
# g = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train.json", "w+")
# g.write("")
# g.close()
# listing = []
for i in files:
    data = [json.loads(line) for line in open(i,"r")]
#     string__ = ','.join(str("\""+item+"\"") for item in data[0]['TEXT'])
    if(len(data[0]['VIOLATED_ARTICLES']) == 0):
#         dictionary = {
# #             "label": "0",
#             "text": ' '.join(data[0]['TEXT'])
#         }
    #   print(j['CONCLUSION'])
        k = k + 1
#         listing.append(dictionary)
    else:
        print(data[0]['VIOLATED_ARTICLES'])
        dictionary = {
#             "label": "1",
            "text": ' '.join(data[0]['TEXT'])
        }
        l = l + 1
        listing.append(dictionary)
# Out:
# ['3', '5', '6']
# ['13', '6']
# ['13', '6']
# ['11', '5', '6']
# ['3']
# ['8']
# ['6', 'P1']
# ['5', '6']
# ['6', 'P1']
# ['8']
# ['5']
# ['3', '5']
# ['8']
# ['13', '3']
# ['3', '5']
# ['3']
# ['6']
# ['3', '8']
# ['3', '5']
# ['13', '6']
# ['6']
# ['11', '5', '6']
# ['5']
# ['8']
# ['5']
# ['13', '6', 'P1']
# ['8']
# ['10']
# ['3']
# ['13', '2']
# ['13', '6']
# ['6', 'P1']
# ['14', 'P1']
# ['8']
# ['3']
# ['6']
# ['6', 'P1']
# ['8']
# ['11']
# ['10', '13', '6']
# ['6']
# ['2']
# ['6']
# ['5']
# ['6', 'P1']
# ['6']
# ['6', 'P1']
# ['6', 'P1']
# ['6']
# ['13', '3', '5']
# ['13', '3']
# ['5']
# ['13', '2', '3', '5']
# ['11', '5', '6']
# ['8']
# ['6']
# ['13', '2', 'P1']
# ['6']
# ['P1']
# ['5']
# ['13', '6']
# ['P1']
# ['6', 'P1']
# ['13', '6']
# ['3']
# ['P7']
# ['3']
# ['13', '3', '6']
# ['13', '3']
# ['6']
# ['13', '6']
# ['13', '3', '5', '8']
# ['6']
# ['3']
# ['8']
# ['18', '5']
# ['P1']
# ['5']
# ['2']
# ['11']
# ['5']
# ['6']
# ['13', '3']
# ['2']
# ['5']
# ['8']
# ['8']
# ...

# %%
files = glob.glob("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/ECHR_Dataset/EN_val/*.json")

# %%
# # g = open(, "r")
# # data = [json.loads(line) for line in open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train.json","r")]

# f = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train.json","r")

# data = json.load(f)
# i = 0
# print(len(data["data"]))
# for j in data["data"]:
#     print(j)
#     if(i>=20):
#         break
#     i= i + 1
# #     if(len(j['violated_articles']) != 0):
# #         print(j['violated_articles'])
# #         i = i + 1
# # print('out now',i)
# g.close()

# k = 0
# g = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train.json", "w+")
# g.write("")
# g.close()
# listing = []

for i in files:
    data = [json.loads(line) for line in open(i,"r")]
#     string__ = ','.join(str("\""+item+"\"") for item in data[0]['TEXT'])
    if(len(data[0]['VIOLATED_ARTICLES']) == 0):
#         print(data[0]['VIOLATED_ARTICLES'])
#         dictionary = {
# #             "label": "0",
#             "text": ' '.join(data[0]['TEXT'])
#         }
    #   print(j['CONCLUSION'])
        k = k + 1
#         listing.append(dictionary)
    else:
        print(data[0]['VIOLATED_ARTICLES'])
        dictionary = {
#             "label": "1",
            "text": ' '.join(data[0]['TEXT'])
        }
        l = l + 1
        listing.append(dictionary)
    
dictionary2 = {"data": listing}
print(len(listing),"listing")
print(k,"k",l,"l")
print(k+l,"k+l")
json_object = json.dumps(dictionary2, indent=2)
#     print(json_object)
g = open("/Users/rohitupadhya/Desktop/TUM/Subjects/Seminar/code/train_pos.json", "a+")
g.write(json_object)
g.write("\n")
    
print('out now')
g.close()
# Out:
# 5525 listing
# 4573 k 5525 l
# 10098 k+l
# out now
